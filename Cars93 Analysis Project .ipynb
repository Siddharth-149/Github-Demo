# %%
# import libraries for analysis
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# warnings 
import warnings
warnings.filterwarnings('ignore')

# %%
# read csv file
df = pd.read_csv(r'Cars93.csv')
df
# Out:
#    Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0         Acura  Integra    Small       12.9   15.9       18.8        25
# 1         Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2          Audi       90  Compact       25.9   29.1       32.3        20
# 3          Audi      100  Midsize       30.8   37.7       44.6        19
# 4           BMW     535i  Midsize       23.7   30.0       36.2        22
# ..          ...      ...      ...        ...    ...        ...       ...
# 88   Volkswagen  Eurovan      Van       16.6   19.7       22.7        17
# 89   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 90   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 91        Volvo      240  Compact       21.8   22.7       23.5        21
# 92        Volvo      850  Midsize       24.8   26.7       28.5        20
#
#     MPG.highway             AirBags DriveTrain  ... Fuel.tank.capacity  \
# 0            31                 NaN      Front  ...               13.2
# 1            25  Driver & Passenger      Front  ...               18.0
# 2            26         Driver only      Front  ...               16.9
# 3            26  Driver & Passenger      Front  ...               21.1
# 4            30         Driver only       Rear  ...               21.1
# ..          ...                 ...        ...  ...                ...
# 88           21                 NaN      Front  ...               21.1
# 89           30                 NaN      Front  ...               18.5
# 90           25                 NaN      Front  ...               18.5
# 91           28         Driver only       Rear  ...               15.8
# 92           28  Driver & Passenger      Front  ...               19.3
#
#     Passengers  Length  Wheelbase  Width Turn.circle  Rear.seat.room  \
# 0            5     177        102     68          37            26.5
# 1            5     195        115     71          38            30.0
# 2            5     180        102     67          37            28.0
# 3            6     193        106     70          37            31.0
# 4            4     186        109     69          39            27.0
# ..         ...     ...        ...    ...         ...             ...
# 88           7     187        115     72          38            34.0
# 89           5     180        103     67          35            31.5
# 90           4     159         97     66          36            26.0
# 91           5     190        104     67          37            29.5
# 92           5     184        105     69          38            30.0
#
#     Luggage.room  Weight   Origin
# 0           11.0    2705  non-USA
# 1           15.0    3560  non-USA
# 2           14.0    3375  non-USA
# 3           17.0    3405  non-USA
# 4           13.0    3640  non-USA
# ..           ...     ...      ...
# 88           NaN    3960  non-USA
# 89          14.0    2985  non-USA
# 90          15.0    2810  non-USA
# 91          14.0    2985  non-USA
# 92          15.0    3245  non-USA
#
# [93 rows x 26 columns]

# %%
# check for top 5 entries
df.head()
# Out:
#   Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0        Acura  Integra    Small       12.9   15.9       18.8        25
# 1        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2         Audi       90  Compact       25.9   29.1       32.3        20
# 3         Audi      100  Midsize       30.8   37.7       44.6        19
# 4          BMW     535i  Midsize       23.7   30.0       36.2        22
#
#    MPG.highway             AirBags DriveTrain  ... Fuel.tank.capacity  \
# 0           31                 NaN      Front  ...               13.2
# 1           25  Driver & Passenger      Front  ...               18.0
# 2           26         Driver only      Front  ...               16.9
# 3           26  Driver & Passenger      Front  ...               21.1
# 4           30         Driver only       Rear  ...               21.1
#
#    Passengers  Length  Wheelbase  Width Turn.circle  Rear.seat.room  \
# 0           5     177        102     68          37            26.5
# 1           5     195        115     71          38            30.0
# 2           5     180        102     67          37            28.0
# 3           6     193        106     70          37            31.0
# 4           4     186        109     69          39            27.0
#
#    Luggage.room  Weight   Origin
# 0          11.0    2705  non-USA
# 1          15.0    3560  non-USA
# 2          14.0    3375  non-USA
# 3          17.0    3405  non-USA
# 4          13.0    3640  non-USA
#
# [5 rows x 26 columns]

# %%
# check for last 5 entries
df.tail()
# Out:
#    Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 88   Volkswagen  Eurovan      Van       16.6   19.7       22.7        17
# 89   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 90   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 91        Volvo      240  Compact       21.8   22.7       23.5        21
# 92        Volvo      850  Midsize       24.8   26.7       28.5        20
#
#     MPG.highway             AirBags DriveTrain  ... Fuel.tank.capacity  \
# 88           21                 NaN      Front  ...               21.1
# 89           30                 NaN      Front  ...               18.5
# 90           25                 NaN      Front  ...               18.5
# 91           28         Driver only       Rear  ...               15.8
# 92           28  Driver & Passenger      Front  ...               19.3
#
#     Passengers  Length  Wheelbase  Width Turn.circle  Rear.seat.room  \
# 88           7     187        115     72          38            34.0
# 89           5     180        103     67          35            31.5
# 90           4     159         97     66          36            26.0
# 91           5     190        104     67          37            29.5
# 92           5     184        105     69          38            30.0
#
#     Luggage.room  Weight   Origin
# 88           NaN    3960  non-USA
# 89          14.0    2985  non-USA
# 90          15.0    2810  non-USA
# 91          14.0    2985  non-USA
# 92          15.0    3245  non-USA
#
# [5 rows x 26 columns]

# %%
# check for rows and column
print('Shape of df is:', df.shape)
# Out:
# Shape of df is: (93, 26)

# %%
# check for information of df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 26 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Manufacturer        93 non-null     object
#  1   Model               93 non-null     object
#  2   Type                93 non-null     object
#  3   Min.Price           93 non-null     float64
#  4   Price               93 non-null     float64
#  5   Max.Price           93 non-null     float64
#  6   MPG.city            93 non-null     int64
#  7   MPG.highway         93 non-null     int64
#  8   AirBags             59 non-null     object
#  9   DriveTrain          93 non-null     object
#  10  Cylinders           93 non-null     object
#  11  EngineSize          93 non-null     float64
#  12  Horsepower          93 non-null     int64
#  13  RPM                 93 non-null     int64
#  14  Rev.per.mile        93 non-null     int64
#  15  Man.trans.avail     93 non-null     object
#  16  Fuel.tank.capacity  93 non-null     float64
#  17  Passengers          93 non-null     int64
#  18  Length              93 non-null     int64
#  19  Wheelbase           93 non-null     int64
#  20  Width               93 non-null     int64
#  21  Turn.circle         93 non-null     int64
#  22  Rear.seat.room      91 non-null     float64
#  23  Luggage.room        82 non-null     float64
#  24  Weight              93 non-null     int64
#  25  Origin              93 non-null     object
# dtypes: float64(7), int64(11), object(8)
# memory usage: 19.0+ KB

# %%
# check for data types of df
df.dtypes
# Out:
# Manufacturer           object
# Model                  object
# Type                   object
# Min.Price             float64
# Price                 float64
# Max.Price             float64
# MPG.city                int64
# MPG.highway             int64
# AirBags                object
# DriveTrain             object
# Cylinders              object
# EngineSize            float64
# Horsepower              int64
# RPM                     int64
# Rev.per.mile            int64
# Man.trans.avail        object
# Fuel.tank.capacity    float64
# Passengers              int64
# Length                  int64
# Wheelbase               int64
# Width                   int64
# Turn.circle             int64
# Rear.seat.room        float64
# Luggage.room          float64
# Weight                  int64
# Origin                 object
# dtype: object

# %%
df.describe()
# Out:
#        Min.Price      Price  Max.Price   MPG.city  MPG.highway  EngineSize  \
# count  93.000000  93.000000  93.000000  93.000000    93.000000   93.000000
# mean   17.125806  19.509677  21.898925  22.365591    29.086022    2.667742
# std     8.746029   9.659430  11.030457   5.619812     5.331726    1.037363
# min     6.700000   7.400000   7.900000  15.000000    20.000000    1.000000
# 25%    10.800000  12.200000  14.700000  18.000000    26.000000    1.800000
# 50%    14.700000  17.700000  19.600000  21.000000    28.000000    2.400000
# 75%    20.300000  23.300000  25.300000  25.000000    31.000000    3.300000
# max    45.400000  61.900000  80.000000  46.000000    50.000000    5.700000
#
#        Horsepower          RPM  Rev.per.mile  Fuel.tank.capacity  Passengers  \
# count   93.000000    93.000000     93.000000           93.000000   93.000000
# mean   143.827957  5280.645161   2332.204301           16.664516    5.086022
# std     52.374410   596.731690    496.506525            3.279370    1.038979
# min     55.000000  3800.000000   1320.000000            9.200000    2.000000
# 25%    103.000000  4800.000000   1985.000000           14.500000    4.000000
# 50%    140.000000  5200.000000   2340.000000           16.400000    5.000000
# 75%    170.000000  5750.000000   2565.000000           18.800000    6.000000
# max    300.000000  6500.000000   3755.000000           27.000000    8.000000
#
#            Length   Wheelbase      Width  Turn.circle  Rear.seat.room  \
# count   93.000000   93.000000  93.000000    93.000000       91.000000
# mean   183.204301  103.946237  69.376344    38.956989       27.829670
# std     14.602382    6.819674   3.778986     3.223265        2.989072
# min    141.000000   90.000000  60.000000    32.000000       19.000000
# 25%    174.000000   98.000000  67.000000    37.000000       26.000000
# 50%    183.000000  103.000000  69.000000    39.000000       27.500000
# 75%    192.000000  110.000000  72.000000    41.000000       30.000000
# max    219.000000  119.000000  78.000000    45.000000       36.000000
#
#        Luggage.room       Weight
# count     82.000000    93.000000
# mean      13.890244  3072.903226
# std        2.997967   589.896510
# min        6.000000  1695.000000
# 25%       12.000000  2620.000000
# 50%       14.000000  3040.000000
# 75%       15.000000  3525.000000
# max       22.000000  4105.000000

# %%
# check for description of df
df.describe(include='all')
# Out:
#        Manufacturer    Model     Type  Min.Price      Price  Max.Price  \
# count            93       93       93  93.000000  93.000000  93.000000
# unique           32       93        6        NaN        NaN        NaN
# top       Chevrolet  Integra  Midsize        NaN        NaN        NaN
# freq              8        1       22        NaN        NaN        NaN
# mean            NaN      NaN      NaN  17.125806  19.509677  21.898925
# std             NaN      NaN      NaN   8.746029   9.659430  11.030457
# min             NaN      NaN      NaN   6.700000   7.400000   7.900000
# 25%             NaN      NaN      NaN  10.800000  12.200000  14.700000
# 50%             NaN      NaN      NaN  14.700000  17.700000  19.600000
# 75%             NaN      NaN      NaN  20.300000  23.300000  25.300000
# max             NaN      NaN      NaN  45.400000  61.900000  80.000000
#
#          MPG.city  MPG.highway      AirBags DriveTrain  ...  \
# count   93.000000    93.000000           59         93  ...
# unique        NaN          NaN            2          3  ...
# top           NaN          NaN  Driver only      Front  ...
# freq          NaN          NaN           43         67  ...
# mean    22.365591    29.086022          NaN        NaN  ...
# std      5.619812     5.331726          NaN        NaN  ...
# min     15.000000    20.000000          NaN        NaN  ...
# 25%     18.000000    26.000000          NaN        NaN  ...
# 50%     21.000000    28.000000          NaN        NaN  ...
# 75%     25.000000    31.000000          NaN        NaN  ...
# max     46.000000    50.000000          NaN        NaN  ...
#
#        Fuel.tank.capacity  Passengers      Length   Wheelbase      Width  \
# count           93.000000   93.000000   93.000000   93.000000  93.000000
# unique                NaN         NaN         NaN         NaN        NaN
# top                   NaN         NaN         NaN         NaN        NaN
# freq                  NaN         NaN         NaN         NaN        NaN
# mean            16.664516    5.086022  183.204301  103.946237  69.376344
# std              3.279370    1.038979   14.602382    6.819674   3.778986
# min              9.200000    2.000000  141.000000   90.000000  60.000000
# 25%             14.500000    4.000000  174.000000   98.000000  67.000000
# 50%             16.400000    5.000000  183.000000  103.000000  69.000000
# 75%             18.800000    6.000000  192.000000  110.000000  72.000000
# max             27.000000    8.000000  219.000000  119.000000  78.000000
#
#        Turn.circle  Rear.seat.room  Luggage.room       Weight  Origin
# count    93.000000       91.000000     82.000000    93.000000      93
# unique         NaN             NaN           NaN          NaN       2
# top            NaN             NaN           NaN          NaN     USA
# freq           NaN             NaN           NaN          NaN      48
# mean     38.956989       27.829670     13.890244  3072.903226     NaN
# std       3.223265        2.989072      2.997967   589.896510     NaN
# min      32.000000       19.000000      6.000000  1695.000000     NaN
# 25%      37.000000       26.000000     12.000000  2620.000000     NaN
# 50%      39.000000       27.500000     14.000000  3040.000000     NaN
# 75%      41.000000       30.000000     15.000000  3525.000000     NaN
# max      45.000000       36.000000     22.000000  4105.000000     NaN
#
# [11 rows x 26 columns]

# %%
# count for unique values
df.nunique()
# Out:
# Manufacturer          32
# Model                 93
# Type                   6
# Min.Price             79
# Price                 81
# Max.Price             79
# MPG.city              21
# MPG.highway           22
# AirBags                2
# DriveTrain             3
# Cylinders              6
# EngineSize            26
# Horsepower            57
# RPM                   24
# Rev.per.mile          78
# Man.trans.avail        2
# Fuel.tank.capacity    38
# Passengers             6
# Length                51
# Wheelbase             27
# Width                 16
# Turn.circle           14
# Rear.seat.room        24
# Luggage.room          16
# Weight                81
# Origin                 2
# dtype: int64

# %%
df.isnull()
# Out:
#     Manufacturer  Model   Type  Min.Price  Price  Max.Price  MPG.city  \
# 0          False  False  False      False  False      False     False
# 1          False  False  False      False  False      False     False
# 2          False  False  False      False  False      False     False
# 3          False  False  False      False  False      False     False
# 4          False  False  False      False  False      False     False
# ..           ...    ...    ...        ...    ...        ...       ...
# 88         False  False  False      False  False      False     False
# 89         False  False  False      False  False      False     False
# 90         False  False  False      False  False      False     False
# 91         False  False  False      False  False      False     False
# 92         False  False  False      False  False      False     False
#
#     MPG.highway  AirBags  DriveTrain  ...  Fuel.tank.capacity  Passengers  \
# 0         False     True       False  ...               False       False
# 1         False    False       False  ...               False       False
# 2         False    False       False  ...               False       False
# 3         False    False       False  ...               False       False
# 4         False    False       False  ...               False       False
# ..          ...      ...         ...  ...                 ...         ...
# 88        False     True       False  ...               False       False
# 89        False     True       False  ...               False       False
# 90        False     True       False  ...               False       False
# 91        False    False       False  ...               False       False
# 92        False    False       False  ...               False       False
#
#     Length  Wheelbase  Width  Turn.circle  Rear.seat.room  Luggage.room  \
# 0    False      False  False        False           False         False
# 1    False      False  False        False           False         False
# 2    False      False  False        False           False         False
# 3    False      False  False        False           False         False
# 4    False      False  False        False           False         False
# ..     ...        ...    ...          ...             ...           ...
# 88   False      False  False        False           False          True
# 89   False      False  False        False           False         False
# 90   False      False  False        False           False         False
# 91   False      False  False        False           False         False
# 92   False      False  False        False           False         False
#
#     Weight  Origin
# 0    False   False
# 1    False   False
# 2    False   False
# 3    False   False
# 4    False   False
# ..     ...     ...
# 88   False   False
# 89   False   False
# 90   False   False
# 91   False   False
# 92   False   False
#
# [93 rows x 26 columns]

# %%
# check for null values in df
df.isnull().sum()
# Out:
# Manufacturer           0
# Model                  0
# Type                   0
# Min.Price              0
# Price                  0
# Max.Price              0
# MPG.city               0
# MPG.highway            0
# AirBags               34
# DriveTrain             0
# Cylinders              0
# EngineSize             0
# Horsepower             0
# RPM                    0
# Rev.per.mile           0
# Man.trans.avail        0
# Fuel.tank.capacity     0
# Passengers             0
# Length                 0
# Wheelbase              0
# Width                  0
# Turn.circle            0
# Rear.seat.room         2
# Luggage.room          11
# Weight                 0
# Origin                 0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 88    False
# 89    False
# 90    False
# 91    False
# 92    False
# Length: 93, dtype: bool

# %%
# check for duplicate values in df
df.duplicated().sum()
# Out:
# 0

# %%
#plot the box plot for Luggage.room
df['Luggage.room'].plot(kind='box')
# Out:
# <Axes: >

# %%
#fill null values of Luggage.room
df['Luggage.room'] = df['Luggage.room'].fillna(df['Luggage.room'].mean())

# %%
#plot the box plot for Rear.seat.room
df['Rear.seat.room'].plot(kind='box')
# Out:
# <Axes: >

# %%
#fill null values of rear.seat.room
df['Rear.seat.room'] = df['Rear.seat.room'].fillna(df['Rear.seat.room'].median())

# %%
#check for null values
df.isnull().sum()
# Out:
# Manufacturer           0
# Model                  0
# Type                   0
# Min.Price              0
# Price                  0
# Max.Price              0
# MPG.city               0
# MPG.highway            0
# AirBags               34
# DriveTrain             0
# Cylinders              0
# EngineSize             0
# Horsepower             0
# RPM                    0
# Rev.per.mile           0
# Man.trans.avail        0
# Fuel.tank.capacity     0
# Passengers             0
# Length                 0
# Wheelbase              0
# Width                  0
# Turn.circle            0
# Rear.seat.room         0
# Luggage.room           0
# Weight                 0
# Origin                 0
# dtype: int64

# %%
#drop columns that not used for analysis
df.drop(labels = ['Manufacturer', 'Model', 'AirBags'],axis=1,inplace=True)

# %%
#check for columns
df.columns
# Out:
# Index(['Type', 'Min.Price', 'Price', 'Max.Price', 'MPG.city', 'MPG.highway',
#        'DriveTrain', 'Cylinders', 'EngineSize', 'Horsepower', 'RPM',
#        'Rev.per.mile', 'Man.trans.avail', 'Fuel.tank.capacity', 'Passengers',
#        'Length', 'Wheelbase', 'Width', 'Turn.circle', 'Rear.seat.room',
#        'Luggage.room', 'Weight', 'Origin'],
#       dtype='object')

# %%
#create categorical and numerical columns
categorical = [i for i in df.columns if df[i].dtype == 'O']
numerical = [i for i in df.columns if df[i].dtype != 'O']
print('Categorical:', categorical)
print('Numerical:', numerical)
# Out:
# Categorical: ['Type', 'DriveTrain', 'Cylinders', 'Man.trans.avail', 'Origin']
# Numerical: ['Min.Price', 'Price', 'Max.Price', 'MPG.city', 'MPG.highway', 'EngineSize', 'Horsepower', 'RPM', 'Rev.per.mile', 'Fuel.tank.capacity', 'Passengers', 'Length', 'Wheelbase', 'Width', 'Turn.circle', 'Rear.seat.room', 'Luggage.room', 'Weight']

# %%
sns.histplot(df['Price'], kde=True)
plt.show()

# %%
sns.boxplot(x="Origin", y="Horsepower", data=df)
plt.show()

# %%
#plot the scatterplot for price and horsepower
sns.scatterplot(x='Price', y='Horsepower', data=df)
plt.show()

# %%
#plot the scatterplot for horsepower and rmp
sns.scatterplot(x='Horsepower', y='RPM', data=df)
plt.show()

# %%
ax = sns.countplot(x='Origin', data=df)

for bars in ax.containers:
    ax.bar_label(bars)

# %%
plt.scatter(df['Horsepower'], df['MPG.highway'], color='yellow')
plt.title("Horsepower vs MPG.highway")
plt.xlabel("Horsepower")
plt.ylabel("MPG (Highway)")
plt.show()

# %%
plt.scatter(df['Horsepower'], df['MPG.city'], color='blue')
plt.title("Horsepower vs MPG.highway")
plt.xlabel("Horsepower")
plt.ylabel("MPG (Highway)")
plt.show()

# %%
for i in categorical:
    for j in numerical:
        print(f'The average {j} for each category in {i} is {df.groupby(i)[j].mean()}')
        print(f'The minimum {j} for each category in {i} is {df.groupby(i)[j].min()}')
        print(f'The maximum {j} for each category in {i} is {df.groupby(i)[j].max()}')
# Out:
# The average Min.Price for each category in Type is Type
# Compact    15.693750
# Large      22.936364
# Midsize    24.113636
# Small       8.428571
# Sporty     16.857143
# Van        16.200000
# Name: Min.Price, dtype: float64
# The minimum Min.Price for each category in Type is Type
# Compact     8.5
# Large      17.5
# Midsize    12.4
# Small       6.7
# Sporty      9.1
# Van        13.6
# Name: Min.Price, dtype: float64
# The maximum Min.Price for each category in Type is Type
# Compact    29.0
# Large      34.4
# Midsize    45.4
# Small      12.9
# Sporty     34.6
# Van        19.5
# Name: Min.Price, dtype: float64
# The average Price for each category in Type is Type
# Compact    18.212500
# Large      24.300000
# Midsize    27.218182
# Small      10.166667
# Sporty     19.392857
# Van        19.100000
# Name: Price, dtype: float64
# The minimum Price for each category in Type is Type
# Compact    11.1
# Large      18.4
# Midsize    13.9
# Small       7.4
# Sporty     10.0
# Van        16.3
# Name: Price, dtype: float64
# The maximum Price for each category in Type is Type
# Compact    31.9
# Large      36.1
# Midsize    61.9
# Small      15.9
# Sporty     38.0
# Van        22.7
# Name: Price, dtype: float64
# The average Max.Price for each category in Type is Type
# Compact    20.725000
# Large      25.672727
# Midsize    30.313636
# Small      11.904762
# Sporty     21.957143
# Van        22.033333
# Name: Max.Price, dtype: float64
# The minimum Max.Price for each category in Type is Type
# Compact    11.4
# Large      18.4
# Midsize    14.9
# Small       7.9
# Sporty     11.0
# Van        18.0
# Name: Max.Price, dtype: float64
# The maximum Max.Price for each category in Type is Type
# Compact    37.1
# Large      37.8
# Midsize    80.0
# Small      18.8
# Sporty     41.5
# Van        26.6
# Name: Max.Price, dtype: float64
# The average MPG.city for each category in Type is Type
# Compact    22.687500
# Large      18.363636
# Midsize    19.545455
# Small      29.857143
# Sporty     21.785714
# Van        17.000000
# Name: MPG.city, dtype: float64
# The minimum MPG.city for each category in Type is Type
# Compact    20
# Large      16
# Midsize    16
# Small      22
# Sporty     17
# Van        15
# Name: MPG.city, dtype: int64
# The maximum MPG.city for each category in Type is Type
# Compact    26
# Large      20
# Midsize    23
# Small      46
# Sporty     30
# Van        18
# Name: MPG.city, dtype: int64
# The average MPG.highway for each category in Type is Type
# Compact    29.875000
# Large      26.727273
# Midsize    26.727273
# Small      35.476190
# Sporty     28.785714
# Van        21.888889
# Name: MPG.highway, dtype: float64
# The minimum MPG.highway for each category in Type is Type
# Compact    26
# Large      25
# Midsize    22
# Small      29
# Sporty     24
# Van        20
# Name: MPG.highway, dtype: int64
# The maximum MPG.highway for each category in Type is Type
# Compact    36
# Large      28
# Midsize    31
# Small      50
# Sporty     36
# Van        24
# Name: MPG.highway, dtype: int64
# The average EngineSize for each category in Type is Type
# Compact    2.331250
# Large      4.209091
# Midsize    3.059091
# Small      1.595238
# Sporty     2.492857
# Van        3.200000
# Name: EngineSize, dtype: float64
# The minimum EngineSize for each category in Type is Type
# Compact    2.0
# Large      3.3
# Midsize    2.0
# Small      1.0
# Sporty     1.3
# Van        2.4
# Name: EngineSize, dtype: float64
# The maximum EngineSize for each category in Type is Type
# Compact    3.0
# Large      5.7
# Midsize    4.6
# Small      2.2
# Sporty     5.7
# Van        4.3
# Name: EngineSize, dtype: float64
# The average Horsepower for each category in Type is Type
# Compact    131.000000
# Large      179.454545
# Midsize    173.090909
# Small       91.000000
# Sporty     160.142857
# Van        149.444444
# Name: Horsepower, dtype: float64
# The minimum Horsepower for each category in Type is Type
# Compact     96
# Large      147
# Midsize    100
# Small       55
# Sporty      90
# Van        109
# Name: Horsepower, dtype: int64
# The maximum Horsepower for each category in Type is Type
# Compact    172
# Large      214
# Midsize    295
# Small      140
# Sporty     300
# Van        170
# Name: Horsepower, dtype: int64
# The average RPM for each category in Type is Type
# Compact    5362.500000
# Large      4672.727273
# Midsize    5336.363636
# Small      5633.333333
# Sporty     5392.857143
# Van        4744.444444
# Name: RPM, dtype: float64
# The minimum RPM for each category in Type is Type
# Compact    4200
# Large      4000
# Midsize    3800
# Small      4800
# Sporty     4600
# Van        4000
# Name: RPM, dtype: int64
# The maximum RPM for each category in Type is Type
# Compact    6000
# Large      5800
# Midsize    6200
# Small      6500
# Sporty     6500
# Van        5000
# Name: RPM, dtype: int64
# The average Rev.per.mile for each category in Type is Type
# Compact    2475.625000
# Large      1626.818182
# Midsize    2221.363636
# Small      2817.380952
# Sporty     2314.285714
# Van        2106.111111
# Name: Rev.per.mile, dtype: float64
# The minimum Rev.per.mile for each category in Type is Type
# Compact    2090
# Large      1320
# Midsize    1690
# Small      2145
# Sporty     1450
# Van        1690
# Name: Rev.per.mile, dtype: int64
# The maximum Rev.per.mile for each category in Type is Type
# Compact    2910
# Large      1990
# Midsize    2595
# Small      3755
# Sporty     3250
# Van        2915
# Name: Rev.per.mile, dtype: int64
# The average Fuel.tank.capacity for each category in Type is Type
# Compact    16.068750
# Large      19.090909
# Midsize    18.450000
# Small      12.619048
# Sporty     15.950000
# Van        20.944444
# Name: Fuel.tank.capacity, dtype: float64
# The minimum Fuel.tank.capacity for each category in Type is Type
# Compact    14.5
# Large      16.0
# Midsize    16.0
# Small       9.2
# Sporty     11.1
# Van        19.6
# Name: Fuel.tank.capacity, dtype: float64
# The maximum Fuel.tank.capacity for each category in Type is Type
# Compact    18.5
# Large      23.0
# Midsize    22.5
# Small      15.9
# Sporty     20.0
# Van        27.0
# Name: Fuel.tank.capacity, dtype: float64
# The average Passengers for each category in Type is Type
# Compact    5.062500
# Large      6.000000
# Midsize    5.136364
# Small      4.619048
# Sporty     3.714286
# Van        7.111111
# Name: Passengers, dtype: float64
# The minimum Passengers for each category in Type is Type
# Compact    4
# Large      6
# Midsize    4
# Small      4
# Sporty     2
# Van        7
# Name: Passengers, dtype: int64
# The maximum Passengers for each category in Type is Type
# Compact    6
# Large      6
# Midsize    6
# Small      5
# Sporty     4
# Van        8
# Name: Passengers, dtype: int64
# The average Length for each category in Type is Type
# Compact    182.125000
# Large      204.818182
# Midsize    192.545455
# Small      167.190476
# Sporty     175.214286
# Van        185.666667
# Name: Length, dtype: float64
# The minimum Length for each category in Type is Type
# Compact    175
# Large      177
# Midsize    184
# Small      141
# Sporty     159
# Van        175
# Name: Length, dtype: int64
# The maximum Length for each category in Type is Type
# Compact    190
# Large      219
# Midsize    205
# Small      177
# Sporty     196
# Van        194
# Name: Length, dtype: int64
# The average Wheelbase for each category in Type is Type
# Compact    102.750000
# Large      113.272727
# Midsize    107.409091
# Small       96.571429
# Sporty      98.142857
# Van        112.444444
# Name: Wheelbase, dtype: float64
# The minimum Wheelbase for each category in Type is Type
# Compact     99
# Large      110
# Midsize    103
# Small       90
# Sporty      94
# Van        110
# Name: Wheelbase, dtype: int64
# The maximum Wheelbase for each category in Type is Type
# Compact    107
# Large      117
# Midsize    115
# Small      103
# Sporty     103
# Van        119
# Name: Wheelbase, dtype: int64
# The average Width for each category in Type is Type
# Compact    67.250000
# Large      74.727273
# Midsize    70.636364
# Small      65.285714
# Sporty     69.285714
# Van        73.222222
# Name: Width, dtype: float64
# The minimum Width for each category in Type is Type
# Compact    66
# Large      69
# Midsize    69
# Small      60
# Sporty     64
# Van        71
# Name: Width, dtype: int64
# The maximum Width for each category in Type is Type
# Compact    69
# Large      78
# Midsize    74
# Small      68
# Sporty     75
# Van        78
# Name: Width, dtype: int64
# The average Turn.circle for each category in Type is Type
# Compact    38.250000
# Large      42.636364
# Midsize    40.181818
# Small      35.142857
# Sporty     38.857143
# Van        41.777778
# Name: Turn.circle, dtype: float64
# The minimum Turn.circle for each category in Type is Type
# Compact    34
# Large      40
# Midsize    37
# Small      32
# Sporty     34
# Van        38
# Name: Turn.circle, dtype: int64
# The maximum Turn.circle for each category in Type is Type
# Compact    41
# Large      45
# Midsize    44
# Small      40
# Sporty     43
# Van        45
# Name: Turn.circle, dtype: int64
# The average Rear.seat.room for each category in Type is Type
# Compact    27.937500
# Large      31.454545
# Midsize    28.568182
# Small      26.452381
# Sporty     24.000000
# Van        30.500000
# Name: Rear.seat.room, dtype: float64
# The minimum Rear.seat.room for each category in Type is Type
# Compact    25.0
# Large      29.5
# Midsize    25.0
# Small      23.5
# Sporty     19.0
# Van        26.5
# Name: Rear.seat.room, dtype: float64
# The maximum Rear.seat.room for each category in Type is Type
# Compact    31.5
# Large      36.0
# Midsize    31.0
# Small      28.0
# Sporty     27.5
# Van        35.0
# Name: Rear.seat.room, dtype: float64
# The average Luggage.room for each category in Type is Type
# Compact    13.687500
# Large      18.272727
# Midsize    15.000000
# Small      12.000000
# Sporty     11.770035
# Van        13.890244
# Name: Luggage.room, dtype: float64
# The minimum Luggage.room for each category in Type is Type
# Compact    12.000000
# Large      15.000000
# Midsize     9.000000
# Small      10.000000
# Sporty      6.000000
# Van        13.890244
# Name: Luggage.room, dtype: float64
# The maximum Luggage.room for each category in Type is Type
# Compact    14.000000
# Large      22.000000
# Midsize    19.000000
# Small      17.000000
# Sporty     18.000000
# Van        13.890244
# Name: Luggage.room, dtype: float64
# The average Weight for each category in Type is Type
# Compact    2918.125000
# Large      3695.454545
# Midsize    3400.000000
# Small      2312.857143
# Sporty     2899.642857
# Van        3830.555556
# Name: Weight, dtype: float64
# The minimum Weight for each category in Type is Type
# Compact    2490
# Large      3470
# Midsize    2880
# Small      1695
# Sporty     2285
# Van        3705
# Name: Weight, dtype: int64
# The maximum Weight for each category in Type is Type
# Compact    3375
# Large      4105
# Midsize    4000
# Small      2705
# Sporty     3805
# Van        4100
# Name: Weight, dtype: int64
# The average Min.Price for each category in DriveTrain is DriveTrain
# 4WD      14.230000
# Front    15.473134
# Rear     25.856250
# Name: Min.Price, dtype: float64
# The minimum Min.Price for each category in DriveTrain is DriveTrain
# 4WD       7.3
# Front     6.7
# Rear     10.8
# Name: Min.Price, dtype: float64
# The maximum Min.Price for each category in DriveTrain is DriveTrain
# 4WD      18.9
# Front    37.5
# Rear     45.4
# Name: Min.Price, dtype: float64
# The average Price for each category in DriveTrain is DriveTrain
# 4WD      17.630000
# Front    17.535821
# Rear     28.950000
# Name: Price, dtype: float64
# The minimum Price for each category in DriveTrain is DriveTrain
# 4WD       8.4
# Front     7.4
# Rear     14.9
# Name: Price, dtype: float64
# The maximum Price for each category in DriveTrain is DriveTrain
# 4WD      25.8
# Front    40.1
# Rear     61.9
# Name: Price, dtype: float64
# The average Max.Price for each category in DriveTrain is DriveTrain
# 4WD      21.060000
# Front    19.601493
# Rear     32.043750
# Name: Max.Price, dtype: float64
# The minimum Max.Price for each category in DriveTrain is DriveTrain
# 4WD       9.5
# Front     7.9
# Rear     14.9
# Name: Max.Price, dtype: float64
# The maximum Max.Price for each category in DriveTrain is DriveTrain
# 4WD      33.1
# Front    44.6
# Rear     80.0
# Name: Max.Price, dtype: float64
# The average MPG.city for each category in DriveTrain is DriveTrain
# 4WD      20.500000
# Front    23.522388
# Rear     18.687500
# Name: MPG.city, dtype: float64
# The minimum MPG.city for each category in DriveTrain is DriveTrain
# 4WD      15
# Front    16
# Rear     16
# Name: MPG.city, dtype: int64
# The maximum MPG.city for each category in DriveTrain is DriveTrain
# 4WD      33
# Front    46
# Rear     22
# Name: MPG.city, dtype: int64
# The average MPG.highway for each category in DriveTrain is DriveTrain
# 4WD      25.800000
# Front    30.238806
# Rear     26.312500
# Name: MPG.highway, dtype: float64
# The minimum MPG.highway for each category in DriveTrain is DriveTrain
# 4WD      20
# Front    21
# Rear     22
# Name: MPG.highway, dtype: int64
# The maximum MPG.highway for each category in DriveTrain is DriveTrain
# 4WD      37
# Front    50
# Rear     30
# Name: MPG.highway, dtype: int64
# The average EngineSize for each category in DriveTrain is DriveTrain
# 4WD      2.570000
# Front    2.444776
# Rear     3.662500
# Name: EngineSize, dtype: float64
# The minimum EngineSize for each category in DriveTrain is DriveTrain
# 4WD      1.2
# Front    1.0
# Rear     1.3
# Name: EngineSize, dtype: float64
# The maximum EngineSize for each category in DriveTrain is DriveTrain
# 4WD      4.3
# Front    4.9
# Rear     5.7
# Name: EngineSize, dtype: float64
# The average Horsepower for each category in DriveTrain is DriveTrain
# 4WD      143.000000
# Front    132.895522
# Rear     190.125000
# Name: Horsepower, dtype: float64
# The minimum Horsepower for each category in DriveTrain is DriveTrain
# 4WD       73
# Front     55
# Rear     105
# Name: Horsepower, dtype: int64
# The maximum Horsepower for each category in DriveTrain is DriveTrain
# 4WD      300
# Front    295
# Rear     300
# Name: Horsepower, dtype: int64
# The average RPM for each category in DriveTrain is DriveTrain
# 4WD      5120.000000
# Front    5374.626866
# Rear     4987.500000
# Name: RPM, dtype: float64
# The minimum RPM for each category in DriveTrain is DriveTrain
# 4WD      4000
# Front    4100
# Rear     3800
# Name: RPM, dtype: int64
# The maximum RPM for each category in DriveTrain is DriveTrain
# 4WD      6000
# Front    6500
# Rear     6500
# Name: RPM, dtype: int64
# The average Rev.per.mile for each category in DriveTrain is DriveTrain
# 4WD      2365.50000
# Front    2418.58209
# Rear     1949.68750
# Name: Rev.per.mile, dtype: float64
# The minimum Rev.per.mile for each category in DriveTrain is DriveTrain
# 4WD      1790
# Front    1510
# Rear     1320
# Name: Rev.per.mile, dtype: int64
# The maximum Rev.per.mile for each category in DriveTrain is DriveTrain
# 4WD      3375
# Front    3755
# Rear     2545
# Name: Rev.per.mile, dtype: int64
# The average Fuel.tank.capacity for each category in DriveTrain is DriveTrain
# 4WD      18.410000
# Front    15.855224
# Rear     18.962500
# Name: Fuel.tank.capacity, dtype: float64
# The minimum Fuel.tank.capacity for each category in DriveTrain is DriveTrain
# 4WD       9.2
# Front    10.0
# Rear     14.5
# Name: Fuel.tank.capacity, dtype: float64
# The maximum Fuel.tank.capacity for each category in DriveTrain is DriveTrain
# 4WD      27.0
# Front    21.1
# Rear     23.0
# Name: Fuel.tank.capacity, dtype: float64
# The average Passengers for each category in DriveTrain is DriveTrain
# 4WD      5.800000
# Front    5.104478
# Rear     4.562500
# Name: Passengers, dtype: float64
# The minimum Passengers for each category in DriveTrain is DriveTrain
# 4WD      4
# Front    4
# Rear     2
# Name: Passengers, dtype: int64
# The maximum Passengers for each category in DriveTrain is DriveTrain
# 4WD      8
# Front    7
# Rear     6
# Name: Passengers, dtype: int64
# The average Length for each category in DriveTrain is DriveTrain
# 4WD      177.500000
# Front    181.447761
# Rear     194.125000
# Name: Length, dtype: float64
# The minimum Length for each category in DriveTrain is DriveTrain
# 4WD      146
# Front    141
# Rear     169
# Name: Length, dtype: int64
# The maximum Length for each category in DriveTrain is DriveTrain
# 4WD      194
# Front    206
# Rear     219
# Name: Length, dtype: int64
# The average Wheelbase for each category in DriveTrain is DriveTrain
# 4WD      104.800
# Front    103.000
# Rear     107.375
# Name: Wheelbase, dtype: float64
# The minimum Wheelbase for each category in DriveTrain is DriveTrain
# 4WD      90
# Front    90
# Rear     96
# Name: Wheelbase, dtype: int64
# The maximum Wheelbase for each category in DriveTrain is DriveTrain
# 4WD      119
# Front    115
# Rear     117
# Name: Wheelbase, dtype: int64
# The average Width for each category in DriveTrain is DriveTrain
# 4WD      69.600000
# Front    68.626866
# Rear     72.375000
# Name: Width, dtype: float64
# The minimum Width for each category in DriveTrain is DriveTrain
# 4WD      60
# Front    63
# Rear     67
# Name: Width, dtype: int64
# The maximum Width for each category in DriveTrain is DriveTrain
# 4WD      78
# Front    74
# Rear     78
# Name: Width, dtype: int64
# The average Turn.circle for each category in DriveTrain is DriveTrain
# 4WD      39.200000
# Front    38.567164
# Rear     40.437500
# Name: Turn.circle, dtype: float64
# The minimum Turn.circle for each category in DriveTrain is DriveTrain
# 4WD      32
# Front    32
# Rear     34
# Name: Turn.circle, dtype: int64
# The maximum Turn.circle for each category in DriveTrain is DriveTrain
# 4WD      45
# Front    44
# Rear     45
# Name: Turn.circle, dtype: int64
# The average Rear.seat.room for each category in DriveTrain is DriveTrain
# 4WD      27.50000
# Front    27.91791
# Rear     27.62500
# Name: Rear.seat.room, dtype: float64
# The minimum Rear.seat.room for each category in DriveTrain is DriveTrain
# 4WD      20.0
# Front    19.0
# Rear     24.0
# Name: Rear.seat.room, dtype: float64
# The maximum Rear.seat.room for each category in DriveTrain is DriveTrain
# 4WD      35.0
# Front    36.0
# Rear     31.5
# Name: Rear.seat.room, dtype: float64
# The average Luggage.room for each category in DriveTrain is DriveTrain
# 4WD      12.745122
# Front    13.754641
# Rear     15.173780
# Name: Luggage.room, dtype: float64
# The minimum Luggage.room for each category in DriveTrain is DriveTrain
# 4WD      8.0
# Front    6.0
# Rear     9.0
# Name: Luggage.room, dtype: float64
# The maximum Luggage.room for each category in DriveTrain is DriveTrain
# 4WD      15.0
# Front    19.0
# Rear     22.0
# Name: Luggage.room, dtype: float64
# The average Weight for each category in DriveTrain is DriveTrain
# 4WD      3305.000000
# Front    2938.955224
# Rear     3488.750000
# Name: Weight, dtype: float64
# The minimum Weight for each category in DriveTrain is DriveTrain
# 4WD      2045
# Front    1695
# Rear     2850
# Name: Weight, dtype: int64
# The maximum Weight for each category in DriveTrain is DriveTrain
# 4WD      4025
# Front    4100
# Rear     4105
# Name: Weight, dtype: int64
# The average Min.Price for each category in Cylinders is Cylinders
# 3          7.100000
# 4         12.404082
# 5         20.700000
# 6         21.506452
# 8         31.857143
# rotary    32.500000
# Name: Min.Price, dtype: float64
# The minimum Min.Price for each category in Cylinders is Cylinders
# 3          6.7
# 4          6.8
# 5         16.6
# 6         13.4
# 8         18.0
# rotary    32.5
# Name: Min.Price, dtype: float64
# The maximum Min.Price for each category in Cylinders is Cylinders
# 3          7.3
# 4         29.0
# 5         24.8
# 6         43.8
# 8         45.4
# rotary    32.5
# Name: Min.Price, dtype: float64
# The average Price for each category in Cylinders is Cylinders
# 3          8.466667
# 4         14.648980
# 5         23.200000
# 6         24.380645
# 8         33.785714
# rotary    32.500000
# Name: Price, dtype: float64
# The minimum Price for each category in Cylinders is Cylinders
# 3          8.4
# 4          7.4
# 5         19.7
# 6         14.9
# 8         18.8
# rotary    32.5
# Name: Price, dtype: float64
# The maximum Price for each category in Cylinders is Cylinders
# 3          8.6
# 4         31.9
# 5         26.7
# 6         61.9
# 8         47.9
# rotary    32.5
# Name: Price, dtype: float64
# The average Max.Price for each category in Cylinders is Cylinders
# 3          9.833333
# 4         16.897959
# 5         25.600000
# 6         27.270968
# 8         35.714286
# rotary    32.500000
# Name: Max.Price, dtype: float64
# The minimum Max.Price for each category in Cylinders is Cylinders
# 3          9.5
# 4          7.9
# 5         22.7
# 6         14.9
# 8         19.6
# rotary    32.5
# Name: Max.Price, dtype: float64
# The maximum Max.Price for each category in Cylinders is Cylinders
# 3         10.0
# 4         37.1
# 5         28.5
# 6         80.0
# 8         50.4
# rotary    32.5
# Name: Max.Price, dtype: float64
# The average MPG.city for each category in Cylinders is Cylinders
# 3         39.333333
# 4         24.857143
# 5         18.500000
# 6         18.419355
# 8         17.000000
# rotary    17.000000
# Name: MPG.city, dtype: float64
# The minimum MPG.city for each category in Cylinders is Cylinders
# 3         33
# 4         18
# 5         17
# 6         15
# 8         16
# rotary    17
# Name: MPG.city, dtype: int64
# The maximum MPG.city for each category in Cylinders is Cylinders
# 3         46
# 4         42
# 5         20
# 6         21
# 8         18
# rotary    17
# Name: MPG.city, dtype: int64
# The average MPG.highway for each category in Cylinders is Cylinders
# 3         43.333333
# 4         31.448980
# 5         24.500000
# 6         25.322581
# 8         25.000000
# rotary    25.000000
# Name: MPG.highway, dtype: float64
# The minimum MPG.highway for each category in Cylinders is Cylinders
# 3         37
# 4         22
# 5         21
# 6         20
# 8         22
# rotary    25
# Name: MPG.highway, dtype: int64
# The maximum MPG.highway for each category in Cylinders is Cylinders
# 3         50
# 4         46
# 5         28
# 6         30
# 8         26
# rotary    25
# Name: MPG.highway, dtype: int64
# The average EngineSize for each category in Cylinders is Cylinders
# 3         1.166667
# 4         2.020408
# 5         2.450000
# 6         3.403226
# 8         4.842857
# rotary    1.300000
# Name: EngineSize, dtype: float64
# The minimum EngineSize for each category in Cylinders is Cylinders
# 3         1.0
# 4         1.3
# 5         2.4
# 6         2.8
# 8         4.5
# rotary    1.3
# Name: EngineSize, dtype: float64
# The maximum EngineSize for each category in Cylinders is Cylinders
# 3         1.3
# 4         3.5
# 5         2.5
# 6         5.7
# 8         5.7
# rotary    1.3
# Name: EngineSize, dtype: float64
# The average Horsepower for each category in Cylinders is Cylinders
# 3          66.000000
# 4         113.469388
# 5         138.500000
# 6         175.580645
# 8         234.714286
# rotary    255.000000
# Name: Horsepower, dtype: float64
# The minimum Horsepower for each category in Cylinders is Cylinders
# 3          55
# 4          63
# 5         109
# 6         140
# 8         170
# rotary    255
# Name: Horsepower, dtype: int64
# The maximum Horsepower for each category in Cylinders is Cylinders
# 3          73
# 4         208
# 5         168
# 6         300
# 8         300
# rotary    255
# Name: Horsepower, dtype: int64
# The average RPM for each category in Cylinders is Cylinders
# 3         5766.666667
# 4         5444.897959
# 5         5350.000000
# 6         5022.580645
# 8         4871.428571
# rotary    6500.000000
# Name: RPM, dtype: float64
# The minimum RPM for each category in Cylinders is Cylinders
# 3         5600
# 4         4200
# 5         4500
# 6         3800
# 8         4100
# rotary    6500
# Name: RPM, dtype: int64
# The maximum RPM for each category in Cylinders is Cylinders
# 3         6000
# 4         6500
# 5         6200
# 6         6000
# 8         6000
# rotary    6500
# Name: RPM, dtype: int64
# The average Rev.per.mile for each category in Cylinders is Cylinders
# 3         3330.000000
# 4         2590.612245
# 5         2612.500000
# 6         1964.838710
# 8         1643.571429
# rotary    2325.000000
# Name: Rev.per.mile, dtype: float64
# The minimum Rev.per.mile for each category in Cylinders is Cylinders
# 3         2875
# 4         2090
# 5         2310
# 6         1320
# 8         1350
# rotary    2325
# Name: Rev.per.mile, dtype: int64
# The maximum Rev.per.mile for each category in Cylinders is Cylinders
# 3         3755
# 4         3505
# 5         2915
# 6         2535
# 8         1985
# rotary    2325
# Name: Rev.per.mile, dtype: int64
# The average Fuel.tank.capacity for each category in Cylinders is Cylinders
# 3         10.133333
# 4         14.914286
# 5         20.200000
# 6         18.861290
# 8         20.500000
# rotary    20.000000
# Name: Fuel.tank.capacity, dtype: float64
# The minimum Fuel.tank.capacity for each category in Cylinders is Cylinders
# 3          9.2
# 4         10.0
# 5         19.3
# 6         15.5
# 8         18.0
# rotary    20.0
# Name: Fuel.tank.capacity, dtype: float64
# The maximum Fuel.tank.capacity for each category in Cylinders is Cylinders
# 3         10.6
# 4         21.1
# 5         21.1
# 6         27.0
# 8         23.0
# rotary    20.0
# Name: Fuel.tank.capacity, dtype: float64
# The average Passengers for each category in Cylinders is Cylinders
# 3         4.000000
# 4         4.836735
# 5         6.000000
# 6         5.612903
# 8         5.142857
# rotary    2.000000
# Name: Passengers, dtype: float64
# The minimum Passengers for each category in Cylinders is Cylinders
# 3         4
# 4         4
# 5         5
# 6         4
# 8         2
# rotary    2
# Name: Passengers, dtype: int64
# The maximum Passengers for each category in Cylinders is Cylinders
# 3         4
# 4         7
# 5         7
# 6         8
# 8         6
# rotary    2
# Name: Passengers, dtype: int64
# The average Length for each category in Cylinders is Cylinders
# 3         152.666667
# 4         177.102041
# 5         185.500000
# 6         191.225806
# 8         204.857143
# rotary    169.000000
# Name: Length, dtype: float64
# The minimum Length for each category in Cylinders is Cylinders
# 3         146
# 4         141
# 5         184
# 6         159
# 8         179
# rotary    169
# Name: Length, dtype: int64
# The maximum Length for each category in Cylinders is Cylinders
# 3         161
# 4         198
# 5         187
# 6         216
# 8         219
# rotary    169
# Name: Length, dtype: int64
# The average Wheelbase for each category in Cylinders is Cylinders
# 3          92.000000
# 4         100.653061
# 5         110.000000
# 6         108.451613
# 8         111.571429
# rotary     96.000000
# Name: Wheelbase, dtype: float64
# The minimum Wheelbase for each category in Cylinders is Cylinders
# 3          90
# 4          90
# 5         105
# 6          97
# 8          96
# rotary     96
# Name: Wheelbase, dtype: int64
# The maximum Wheelbase for each category in Cylinders is Cylinders
# 3          93
# 4         113
# 5         115
# 6         119
# 8         117
# rotary     96
# Name: Wheelbase, dtype: int64
# The average Width for each category in Cylinders is Cylinders
# 3         62.000000
# 4         67.183673
# 5         70.500000
# 6         72.225806
# 8         75.000000
# rotary    69.000000
# Name: Width, dtype: float64
# The minimum Width for each category in Cylinders is Cylinders
# 3         60
# 4         63
# 5         69
# 6         66
# 8         72
# rotary    69
# Name: Width, dtype: int64
# The maximum Width for each category in Cylinders is Cylinders
# 3         63
# 4         71
# 5         72
# 6         78
# 8         78
# rotary    69
# Name: Width, dtype: int64
# The average Turn.circle for each category in Cylinders is Cylinders
# 3         33.333333
# 4         37.530612
# 5         38.000000
# 6         40.935484
# 8         43.142857
# rotary    37.000000
# Name: Turn.circle, dtype: float64
# The minimum Turn.circle for each category in Cylinders is Cylinders
# 3         32
# 4         32
# 5         38
# 6         36
# 8         42
# rotary    37
# Name: Turn.circle, dtype: int64
# The maximum Turn.circle for each category in Cylinders is Cylinders
# 3         34
# 4         42
# 5         38
# 6         45
# 8         45
# rotary    37
# Name: Turn.circle, dtype: int64
# The average Rear.seat.room for each category in Cylinders is Cylinders
# 3         26.166667
# 4         26.887755
# 5         32.000000
# 6         28.596774
# 8         30.500000
# rotary    27.500000
# Name: Rear.seat.room, dtype: float64
# The minimum Rear.seat.room for each category in Cylinders is Cylinders
# 3         23.5
# 4         19.0
# 5         30.0
# 6         20.0
# 8         27.5
# rotary    27.5
# Name: Rear.seat.room, dtype: float64
# The maximum Rear.seat.room for each category in Cylinders is Cylinders
# 3         27.5
# 4         35.0
# 5         34.0
# 6         36.0
# 8         35.0
# rotary    27.5
# Name: Rear.seat.room, dtype: float64
# The average Luggage.room for each category in Cylinders is Cylinders
# 3         10.000000
# 4         12.895719
# 5         14.445122
# 6         14.942958
# 8         17.698606
# rotary    13.890244
# Name: Luggage.room, dtype: float64
# The minimum Luggage.room for each category in Cylinders is Cylinders
# 3         10.000000
# 4          6.000000
# 5         13.890244
# 6          9.000000
# 8         13.890244
# rotary    13.890244
# Name: Luggage.room, dtype: float64
# The maximum Luggage.room for each category in Cylinders is Cylinders
# 3         10.000000
# 4         18.000000
# 5         15.000000
# 6         21.000000
# 8         22.000000
# rotary    13.890244
# Name: Luggage.room, dtype: float64
# The average Weight for each category in Cylinders is Cylinders
# 3         1901.666667
# 4         2710.000000
# 5         3602.500000
# 6         3559.193548
# 8         3835.714286
# rotary    2895.000000
# Name: Weight, dtype: float64
# The minimum Weight for each category in Cylinders is Cylinders
# 3         1695
# 4         1845
# 5         3245
# 6         2810
# 8         3380
# rotary    2895
# Name: Weight, dtype: int64
# The maximum Weight for each category in Cylinders is Cylinders
# 3         2045
# 4         3785
# 5         3960
# 6         4105
# 8         4055
# rotary    2895
# Name: Weight, dtype: int64
# The average Min.Price for each category in Man.trans.avail is Man.trans.avail
# No     21.637500
# Yes    14.759016
# Name: Min.Price, dtype: float64
# The minimum Min.Price for each category in Man.trans.avail is Man.trans.avail
# No     13.0
# Yes     6.7
# Name: Min.Price, dtype: float64
# The maximum Min.Price for each category in Man.trans.avail is Man.trans.avail
# No     45.4
# Yes    34.7
# Name: Min.Price, dtype: float64
# The average Price for each category in Man.trans.avail is Man.trans.avail
# No     23.840625
# Yes    17.237705
# Name: Price, dtype: float64
# The minimum Price for each category in Man.trans.avail is Man.trans.avail
# No     13.5
# Yes     7.4
# Name: Price, dtype: float64
# The maximum Price for each category in Man.trans.avail is Man.trans.avail
# No     61.9
# Yes    38.0
# Name: Price, dtype: float64
# The average Max.Price for each category in Man.trans.avail is Man.trans.avail
# No     26.062500
# Yes    19.714754
# Name: Max.Price, dtype: float64
# The minimum Max.Price for each category in Man.trans.avail is Man.trans.avail
# No     14.0
# Yes     7.9
# Name: Max.Price, dtype: float64
# The maximum Max.Price for each category in Man.trans.avail is Man.trans.avail
# No     80.0
# Yes    44.6
# Name: Max.Price, dtype: float64
# The average MPG.city for each category in Man.trans.avail is Man.trans.avail
# No     18.937500
# Yes    24.163934
# Name: MPG.city, dtype: float64
# The minimum MPG.city for each category in Man.trans.avail is Man.trans.avail
# No     15
# Yes    15
# Name: MPG.city, dtype: int64
# The maximum MPG.city for each category in Man.trans.avail is Man.trans.avail
# No     24
# Yes    46
# Name: MPG.city, dtype: int64
# The average MPG.highway for each category in Man.trans.avail is Man.trans.avail
# No     26.125000
# Yes    30.639344
# Name: MPG.highway, dtype: float64
# The minimum MPG.highway for each category in Man.trans.avail is Man.trans.avail
# No     20
# Yes    20
# Name: MPG.highway, dtype: int64
# The maximum MPG.highway for each category in Man.trans.avail is Man.trans.avail
# No     31
# Yes    50
# Name: MPG.highway, dtype: int64
# The average EngineSize for each category in Man.trans.avail is Man.trans.avail
# No     3.571875
# Yes    2.193443
# Name: EngineSize, dtype: float64
# The minimum EngineSize for each category in Man.trans.avail is Man.trans.avail
# No     2.2
# Yes    1.0
# Name: EngineSize, dtype: float64
# The maximum EngineSize for each category in Man.trans.avail is Man.trans.avail
# No     5.7
# Yes    5.7
# Name: EngineSize, dtype: float64
# The average Horsepower for each category in Man.trans.avail is Man.trans.avail
# No     169.218750
# Yes    130.508197
# Name: Horsepower, dtype: float64
# The minimum Horsepower for each category in Man.trans.avail is Man.trans.avail
# No     100
# Yes     55
# Name: Horsepower, dtype: int64
# The maximum Horsepower for each category in Man.trans.avail is Man.trans.avail
# No     295
# Yes    300
# Name: Horsepower, dtype: int64
# The average RPM for each category in Man.trans.avail is Man.trans.avail
# No     4928.12500
# Yes    5465.57377
# Name: RPM, dtype: float64
# The minimum RPM for each category in Man.trans.avail is Man.trans.avail
# No     3800
# Yes    4200
# Name: RPM, dtype: int64
# The maximum RPM for each category in Man.trans.avail is Man.trans.avail
# No     6000
# Yes    6500
# Name: RPM, dtype: int64
# The average Rev.per.mile for each category in Man.trans.avail is Man.trans.avail
# No     1923.593750
# Yes    2546.557377
# Name: Rev.per.mile, dtype: float64
# The minimum Rev.per.mile for each category in Man.trans.avail is Man.trans.avail
# No     1320
# Yes    1450
# Name: Rev.per.mile, dtype: int64
# The maximum Rev.per.mile for each category in Man.trans.avail is Man.trans.avail
# No     2595
# Yes    3755
# Name: Rev.per.mile, dtype: int64
# The average Fuel.tank.capacity for each category in Man.trans.avail is Man.trans.avail
# No     18.840625
# Yes    15.522951
# Name: Fuel.tank.capacity, dtype: float64
# The minimum Fuel.tank.capacity for each category in Man.trans.avail is Man.trans.avail
# No     15.2
# Yes     9.2
# Name: Fuel.tank.capacity, dtype: float64
# The maximum Fuel.tank.capacity for each category in Man.trans.avail is Man.trans.avail
# No     27.0
# Yes    21.1
# Name: Fuel.tank.capacity, dtype: float64
# The average Passengers for each category in Man.trans.avail is Man.trans.avail
# No     5.906250
# Yes    4.655738
# Name: Passengers, dtype: float64
# The minimum Passengers for each category in Man.trans.avail is Man.trans.avail
# No     5
# Yes    2
# Name: Passengers, dtype: int64
# The maximum Passengers for each category in Man.trans.avail is Man.trans.avail
# No     8
# Yes    7
# Name: Passengers, dtype: int64
# The average Length for each category in Man.trans.avail is Man.trans.avail
# No     196.156250
# Yes    176.409836
# Name: Length, dtype: float64
# The minimum Length for each category in Man.trans.avail is Man.trans.avail
# No     175
# Yes    141
# Name: Length, dtype: int64
# The maximum Length for each category in Man.trans.avail is Man.trans.avail
# No     219
# Yes    196
# Name: Length, dtype: int64
# The average Wheelbase for each category in Man.trans.avail is Man.trans.avail
# No     110.062500
# Yes    100.737705
# Name: Wheelbase, dtype: float64
# The minimum Wheelbase for each category in Man.trans.avail is Man.trans.avail
# No     103
# Yes     90
# Name: Wheelbase, dtype: int64
# The maximum Wheelbase for each category in Man.trans.avail is Man.trans.avail
# No     117
# Yes    119
# Name: Wheelbase, dtype: int64
# The average Width for each category in Man.trans.avail is Man.trans.avail
# No     72.625000
# Yes    67.672131
# Name: Width, dtype: float64
# The minimum Width for each category in Man.trans.avail is Man.trans.avail
# No     67
# Yes    60
# Name: Width, dtype: int64
# The maximum Width for each category in Man.trans.avail is Man.trans.avail
# No     78
# Yes    75
# Name: Width, dtype: int64
# The average Turn.circle for each category in Man.trans.avail is Man.trans.avail
# No     41.68750
# Yes    37.52459
# Name: Turn.circle, dtype: float64
# The minimum Turn.circle for each category in Man.trans.avail is Man.trans.avail
# No     37
# Yes    32
# Name: Turn.circle, dtype: int64
# The maximum Turn.circle for each category in Man.trans.avail is Man.trans.avail
# No     45
# Yes    45
# Name: Turn.circle, dtype: int64
# The average Rear.seat.room for each category in Man.trans.avail is Man.trans.avail
# No     29.687500
# Yes    26.844262
# Name: Rear.seat.room, dtype: float64
# The minimum Rear.seat.room for each category in Man.trans.avail is Man.trans.avail
# No     26.5
# Yes    19.0
# Name: Rear.seat.room, dtype: float64
# The maximum Rear.seat.room for each category in Man.trans.avail is Man.trans.avail
# No     36.0
# Yes    35.0
# Name: Rear.seat.room, dtype: float64
# The average Luggage.room for each category in Man.trans.avail is Man.trans.avail
# No     16.073171
# Yes    12.745102
# Name: Luggage.room, dtype: float64
# The minimum Luggage.room for each category in Man.trans.avail is Man.trans.avail
# No     13.890244
# Yes     6.000000
# Name: Luggage.room, dtype: float64
# The maximum Luggage.room for each category in Man.trans.avail is Man.trans.avail
# No     22.0
# Yes    18.0
# Name: Luggage.room, dtype: float64
# The average Weight for each category in Man.trans.avail is Man.trans.avail
# No     3568.750000
# Yes    2812.786885
# Name: Weight, dtype: float64
# The minimum Weight for each category in Man.trans.avail is Man.trans.avail
# No     2880
# Yes    1695
# Name: Weight, dtype: int64
# The maximum Weight for each category in Man.trans.avail is Man.trans.avail
# No     4105
# Yes    3960
# Name: Weight, dtype: int64
# The average Min.Price for each category in Origin is Origin
# USA        16.535417
# non-USA    17.755556
# Name: Min.Price, dtype: float64
# The minimum Min.Price for each category in Origin is Origin
# USA        6.9
# non-USA    6.7
# Name: Min.Price, dtype: float64
# The maximum Min.Price for each category in Origin is Origin
# USA        37.5
# non-USA    45.4
# Name: Min.Price, dtype: float64
# The average Price for each category in Origin is Origin
# USA        18.572917
# non-USA    20.508889
# Name: Price, dtype: float64
# The minimum Price for each category in Origin is Origin
# USA        7.4
# non-USA    8.0
# Name: Price, dtype: float64
# The maximum Price for each category in Origin is Origin
# USA        40.1
# non-USA    61.9
# Name: Price, dtype: float64
# The average Max.Price for each category in Origin is Origin
# USA        20.627083
# non-USA    23.255556
# Name: Max.Price, dtype: float64
# The minimum Max.Price for each category in Origin is Origin
# USA        7.9
# non-USA    9.1
# Name: Max.Price, dtype: float64
# The maximum Max.Price for each category in Origin is Origin
# USA        42.7
# non-USA    80.0
# Name: Max.Price, dtype: float64
# The average MPG.city for each category in Origin is Origin
# USA        20.958333
# non-USA    23.866667
# Name: MPG.city, dtype: float64
# The minimum MPG.city for each category in Origin is Origin
# USA        15
# non-USA    17
# Name: MPG.city, dtype: int64
# The maximum MPG.city for each category in Origin is Origin
# USA        31
# non-USA    46
# Name: MPG.city, dtype: int64
# The average MPG.highway for each category in Origin is Origin
# USA        28.145833
# non-USA    30.088889
# Name: MPG.highway, dtype: float64
# The minimum MPG.highway for each category in Origin is Origin
# USA        20
# non-USA    21
# Name: MPG.highway, dtype: int64
# The maximum MPG.highway for each category in Origin is Origin
# USA        41
# non-USA    50
# Name: MPG.highway, dtype: int64
# The average EngineSize for each category in Origin is Origin
# USA        3.066667
# non-USA    2.242222
# Name: EngineSize, dtype: float64
# The minimum EngineSize for each category in Origin is Origin
# USA        1.3
# non-USA    1.0
# Name: EngineSize, dtype: float64
# The maximum EngineSize for each category in Origin is Origin
# USA        5.7
# non-USA    4.5
# Name: EngineSize, dtype: float64
# The average Horsepower for each category in Origin is Origin
# USA        147.520833
# non-USA    139.888889
# Name: Horsepower, dtype: float64
# The minimum Horsepower for each category in Origin is Origin
# USA        63
# non-USA    55
# Name: Horsepower, dtype: int64
# The maximum Horsepower for each category in Origin is Origin
# USA        300
# non-USA    278
# Name: Horsepower, dtype: int64
# The average RPM for each category in Origin is Origin
# USA        4990.625
# non-USA    5590.000
# Name: RPM, dtype: float64
# The minimum RPM for each category in Origin is Origin
# USA        3800
# non-USA    4500
# Name: RPM, dtype: int64
# The maximum RPM for each category in Origin is Origin
# USA        6500
# non-USA    6500
# Name: RPM, dtype: int64
# The average Rev.per.mile for each category in Origin is Origin
# USA        2118.750000
# non-USA    2559.888889
# Name: Rev.per.mile, dtype: float64
# The minimum Rev.per.mile for each category in Origin is Origin
# USA        1320
# non-USA    1955
# Name: Rev.per.mile, dtype: int64
# The maximum Rev.per.mile for each category in Origin is Origin
# USA        3285
# non-USA    3755
# Name: Rev.per.mile, dtype: int64
# The average Fuel.tank.capacity for each category in Origin is Origin
# USA        17.052083
# non-USA    16.251111
# Name: Fuel.tank.capacity, dtype: float64
# The minimum Fuel.tank.capacity for each category in Origin is Origin
# USA        10.0
# non-USA     9.2
# Name: Fuel.tank.capacity, dtype: float64
# The maximum Fuel.tank.capacity for each category in Origin is Origin
# USA        27.0
# non-USA    22.5
# Name: Fuel.tank.capacity, dtype: float64
# The average Passengers for each category in Origin is Origin
# USA        5.333333
# non-USA    4.822222
# Name: Passengers, dtype: float64
# The minimum Passengers for each category in Origin is Origin
# USA        2
# non-USA    2
# Name: Passengers, dtype: int64
# The maximum Passengers for each category in Origin is Origin
# USA        8
# non-USA    7
# Name: Passengers, dtype: int64
# The average Length for each category in Origin is Origin
# USA        188.312500
# non-USA    177.755556
# Name: Length, dtype: float64
# The minimum Length for each category in Origin is Origin
# USA        141
# non-USA    146
# Name: Length, dtype: int64
# The maximum Length for each category in Origin is Origin
# USA        219
# non-USA    200
# Name: Length, dtype: int64
# The average Wheelbase for each category in Origin is Origin
# USA        105.729167
# non-USA    102.044444
# Name: Wheelbase, dtype: float64
# The minimum Wheelbase for each category in Origin is Origin
# USA        90
# non-USA    90
# Name: Wheelbase, dtype: int64
# The maximum Wheelbase for each category in Origin is Origin
# USA        119
# non-USA    115
# Name: Wheelbase, dtype: int64
# The average Width for each category in Origin is Origin
# USA        70.958333
# non-USA    67.688889
# Name: Width, dtype: float64
# The minimum Width for each category in Origin is Origin
# USA        63
# non-USA    60
# Name: Width, dtype: int64
# The maximum Width for each category in Origin is Origin
# USA        78
# non-USA    74
# Name: Width, dtype: int64
# The average Turn.circle for each category in Origin is Origin
# USA        40.479167
# non-USA    37.333333
# Name: Turn.circle, dtype: float64
# The minimum Turn.circle for each category in Origin is Origin
# USA        32
# non-USA    32
# Name: Turn.circle, dtype: int64
# The maximum Turn.circle for each category in Origin is Origin
# USA        45
# non-USA    43
# Name: Turn.circle, dtype: int64
# The average Rear.seat.room for each category in Origin is Origin
# USA        28.114583
# non-USA    27.511111
# Name: Rear.seat.room, dtype: float64
# The minimum Rear.seat.room for each category in Origin is Origin
# USA        19.0
# non-USA    23.0
# Name: Rear.seat.room, dtype: float64
# The maximum Rear.seat.room for each category in Origin is Origin
# USA        36.0
# non-USA    35.0
# Name: Rear.seat.room, dtype: float64
# The average Luggage.room for each category in Origin is Origin
# USA        14.757114
# non-USA    12.965583
# Name: Luggage.room, dtype: float64
# The minimum Luggage.room for each category in Origin is Origin
# USA        6.0
# non-USA    8.0
# Name: Luggage.room, dtype: float64
# The maximum Luggage.room for each category in Origin is Origin
# USA        22.0
# non-USA    17.0
# Name: Luggage.room, dtype: float64
# The average Weight for each category in Origin is Origin
# USA        3195.312500
# non-USA    2942.333333
# Name: Weight, dtype: float64
# The minimum Weight for each category in Origin is Origin
# USA        1845
# non-USA    1695
# Name: Weight, dtype: int64
# The maximum Weight for each category in Origin is Origin
# USA        4105
# non-USA    4100
# Name: Weight, dtype: int64

# %%
for i in categorical:
    for j in numerical:
        print(f'The average {j} for each category in {i} is {df.groupby(i)[j].mean().plot(kind='bar')}')
# Out:
# The average Min.Price for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average Price for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average Max.Price for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average MPG.city for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average MPG.highway for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average EngineSize for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average Horsepower for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average RPM for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average Rev.per.mile for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average Fuel.tank.capacity for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average Passengers for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average Length for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average Wheelbase for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average Width for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average Turn.circle for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average Rear.seat.room for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average Luggage.room for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average Weight for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average Min.Price for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average Price for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average Max.Price for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average MPG.city for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average MPG.highway for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average EngineSize for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average Horsepower for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average RPM for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average Rev.per.mile for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average Fuel.tank.capacity for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average Passengers for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average Length for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average Wheelbase for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average Width for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average Turn.circle for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average Rear.seat.room for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average Luggage.room for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average Weight for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average Min.Price for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average Price for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average Max.Price for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average MPG.city for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average MPG.highway for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average EngineSize for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average Horsepower for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average RPM for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average Rev.per.mile for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average Fuel.tank.capacity for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average Passengers for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average Length for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average Wheelbase for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average Width for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average Turn.circle for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average Rear.seat.room for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average Luggage.room for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average Weight for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average Min.Price for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average Price for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average Max.Price for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average MPG.city for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average MPG.highway for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average EngineSize for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average Horsepower for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average RPM for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average Rev.per.mile for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average Fuel.tank.capacity for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average Passengers for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average Length for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average Wheelbase for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average Width for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average Turn.circle for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average Rear.seat.room for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average Luggage.room for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average Weight for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average Min.Price for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average Price for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average Max.Price for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average MPG.city for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average MPG.highway for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average EngineSize for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average Horsepower for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average RPM for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average Rev.per.mile for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average Fuel.tank.capacity for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average Passengers for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average Length for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average Wheelbase for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average Width for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average Turn.circle for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average Rear.seat.room for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average Luggage.room for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average Weight for each category in Origin is Axes(0.125,0.11;0.775x0.77)

# %%
for i in categorical:
    for j in numerical:
        print(f'The average {j} for each category in {i} is {df.groupby(i)[j].min().plot(kind='bar')}')
# Out:
# The average Min.Price for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average Price for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average Max.Price for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average MPG.city for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average MPG.highway for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average EngineSize for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average Horsepower for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average RPM for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average Rev.per.mile for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average Fuel.tank.capacity for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average Passengers for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average Length for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average Wheelbase for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average Width for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average Turn.circle for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average Rear.seat.room for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average Luggage.room for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average Weight for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average Min.Price for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average Price for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average Max.Price for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average MPG.city for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average MPG.highway for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average EngineSize for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average Horsepower for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average RPM for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average Rev.per.mile for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average Fuel.tank.capacity for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average Passengers for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average Length for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average Wheelbase for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average Width for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average Turn.circle for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average Rear.seat.room for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average Luggage.room for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average Weight for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average Min.Price for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average Price for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average Max.Price for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average MPG.city for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average MPG.highway for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average EngineSize for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average Horsepower for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average RPM for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average Rev.per.mile for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average Fuel.tank.capacity for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average Passengers for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average Length for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average Wheelbase for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average Width for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average Turn.circle for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average Rear.seat.room for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average Luggage.room for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average Weight for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average Min.Price for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average Price for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average Max.Price for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average MPG.city for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average MPG.highway for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average EngineSize for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average Horsepower for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average RPM for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average Rev.per.mile for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average Fuel.tank.capacity for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average Passengers for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average Length for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average Wheelbase for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average Width for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average Turn.circle for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average Rear.seat.room for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average Luggage.room for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average Weight for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average Min.Price for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average Price for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average Max.Price for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average MPG.city for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average MPG.highway for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average EngineSize for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average Horsepower for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average RPM for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average Rev.per.mile for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average Fuel.tank.capacity for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average Passengers for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average Length for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average Wheelbase for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average Width for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average Turn.circle for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average Rear.seat.room for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average Luggage.room for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average Weight for each category in Origin is Axes(0.125,0.11;0.775x0.77)

# %%
for i in categorical:
    for j in numerical:
        print(f'The average {j} for each category in {i} is {df.groupby(i)[j].max().plot(kind='bar')}')
# Out:
# The average Min.Price for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average Price for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average Max.Price for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average MPG.city for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average MPG.highway for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average EngineSize for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average Horsepower for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average RPM for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average Rev.per.mile for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average Fuel.tank.capacity for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average Passengers for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average Length for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average Wheelbase for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average Width for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average Turn.circle for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average Rear.seat.room for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average Luggage.room for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average Weight for each category in Type is Axes(0.125,0.11;0.775x0.77)
# The average Min.Price for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average Price for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average Max.Price for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average MPG.city for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average MPG.highway for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average EngineSize for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average Horsepower for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average RPM for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average Rev.per.mile for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average Fuel.tank.capacity for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average Passengers for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average Length for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average Wheelbase for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average Width for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average Turn.circle for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average Rear.seat.room for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average Luggage.room for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average Weight for each category in DriveTrain is Axes(0.125,0.11;0.775x0.77)
# The average Min.Price for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average Price for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average Max.Price for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average MPG.city for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average MPG.highway for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average EngineSize for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average Horsepower for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average RPM for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average Rev.per.mile for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average Fuel.tank.capacity for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average Passengers for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average Length for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average Wheelbase for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average Width for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average Turn.circle for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average Rear.seat.room for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average Luggage.room for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average Weight for each category in Cylinders is Axes(0.125,0.11;0.775x0.77)
# The average Min.Price for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average Price for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average Max.Price for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average MPG.city for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average MPG.highway for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average EngineSize for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average Horsepower for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average RPM for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average Rev.per.mile for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average Fuel.tank.capacity for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average Passengers for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average Length for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average Wheelbase for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average Width for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average Turn.circle for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average Rear.seat.room for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average Luggage.room for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average Weight for each category in Man.trans.avail is Axes(0.125,0.11;0.775x0.77)
# The average Min.Price for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average Price for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average Max.Price for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average MPG.city for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average MPG.highway for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average EngineSize for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average Horsepower for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average RPM for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average Rev.per.mile for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average Fuel.tank.capacity for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average Passengers for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average Length for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average Wheelbase for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average Width for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average Turn.circle for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average Rear.seat.room for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average Luggage.room for each category in Origin is Axes(0.125,0.11;0.775x0.77)
# The average Weight for each category in Origin is Axes(0.125,0.11;0.775x0.77)
